# %% [markdown]
# # Testing for Alpha Vantage api

# %%
import requests
import json

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=1RZHEEKZF7GJSSST&time_from=20250101T0000&time_to=20250131T2359&sort=EARLIEST&limit=1000'
r = requests.get(url)
data = r.json()
pretty_data = json.dumps(data,indent=5)
print(pretty_data)
with open('data.json','w',encoding='utf-8') as f:
    json.dump(data,f,ensure_ascii=False,indent=5)
# Out:
# {
#      "items": "470",
#      "sentiment_score_definition": "x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish",
#      "relevance_score_definition": "0 < x <= 1, with a higher score indicating higher relevance.",
#      "feed": [
#           {
#                "title": "10 Stock Market Predictions for 2025",
#                "url": "https://www.fool.com/investing/2025/01/01/10-stock-market-predictions-for-2025/",
#                "time_published": "20250101T100600",
#                "authors": [
#                     "Sean Williams"
#                ],
#                "summary": "Here's what to expect from the stock market, along with some of Wall Street's hottest trends and most influential businesses, in the new year.",
#                "banner_image": "https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F802285%2Fbear-market-stock-chart-quarter-report-financial-metrics-invest-getty.jpg&op=resize&w=700",
#                "source": "Motley Fool",
#                "category_within_source": "n/a",
#                "source_domain": "www.fool.com",
#                "topics": [
#                     {
#                          "topic": "Life Sciences",
#                          "relevance_score": "0.2"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.2"
#                     },
#                     {
#                          "topic": "Finance",
#                          "relevance_score": "0.2"
#                     },
#                     {
#                          "topic": "Blockchain",
#                          "relevance_score": "0.158519"
#                     },
#                     {
#                          "topic": "Economy - Monetary",
#                          "relevance_score": "0.682689"
#                     },
#                     {
#                          "topic": "Retail & Wholesale",
#                          "relevance_score": "0.2"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "1.0"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.2"
#                     },
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.451494"
#                     }
#                ],
#                "overall_sentiment_score": 0.077051,
#                "overall_sentiment_label": "Neutral",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.108466",
#                          "ticker_sentiment_score": "0.130801",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "META",
#                          "relevance_score": "0.065209",
#                          "ticker_sentiment_score": "0.096486",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.08687",
#                          "ticker_sentiment_score": "0.08002",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.08687",
#                          "ticker_sentiment_score": "0.151611",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "COST",
#                          "relevance_score": "0.043499",
#                          "ticker_sentiment_score": "-0.00793",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "TSLA",
#                          "relevance_score": "0.043499",
#                          "ticker_sentiment_score": "0.07165",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "BAC",
#                          "relevance_score": "0.021758",
#                          "ticker_sentiment_score": "0.07063",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "JNJ",
#                          "relevance_score": "0.043499",
#                          "ticker_sentiment_score": "0.153801",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "CMG",
#                          "relevance_score": "0.021758",
#                          "ticker_sentiment_score": "-0.07189",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "IVZ",
#                          "relevance_score": "0.021758",
#                          "ticker_sentiment_score": "0.147825",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "PFE",
#                          "relevance_score": "0.043499",
#                          "ticker_sentiment_score": "0.153801",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "CRYPTO:BTC",
#                          "relevance_score": "0.08687",
#                          "ticker_sentiment_score": "0.032885",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "Should Vanguard S&P 500 Growth ETF  ( VOOG )  Be on Your Investing Radar?",
#                "url": "https://www.zacks.com/stock/news/2390296/should-vanguard-sp-500-growth-etf-voog-be-on-your-investing-radar",
#                "time_published": "20250101T112008",
#                "authors": [
#                     "Zacks Equity Research"
#                ],
#                "summary": "Style Box ETF report for ...",
#                "banner_image": "https://staticx-tuner.zacks.com/images/default_article_images/default338.jpg",
#                "source": "Zacks Commentary",
#                "category_within_source": "n/a",
#                "source_domain": "www.zacks.com",
#                "topics": [
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "1.0"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.310843"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Finance",
#                          "relevance_score": "0.333333"
#                     }
#                ],
#                "overall_sentiment_score": 0.262962,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.125134",
#                          "ticker_sentiment_score": "0.069019",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.125134",
#                          "ticker_sentiment_score": "0.069019",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.125134",
#                          "ticker_sentiment_score": "0.069019",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "IVZ",
#                          "relevance_score": "0.125134",
#                          "ticker_sentiment_score": "0.104891",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "Should Vanguard S&P 500 ETF  ( VOO )  Be on Your Investing Radar?",
#                "url": "https://www.zacks.com/stock/news/2390295/should-vanguard-sp-500-etf-voo-be-on-your-investing-radar",
#                "time_published": "20250101T112008",
#                "authors": [
#                     "Zacks Equity Research"
#                ],
#                "summary": "Style Box ETF report for ...",
#                "banner_image": "https://staticx-tuner.zacks.com/images/default_article_images/default291.jpg",
#                "source": "Zacks Commentary",
#                "category_within_source": "n/a",
#                "source_domain": "www.zacks.com",
#                "topics": [
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.5"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "1.0"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.5"
#                     }
#                ],
#                "overall_sentiment_score": 0.200713,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.138066",
#                          "ticker_sentiment_score": "0.072464",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.138066",
#                          "ticker_sentiment_score": "0.072464",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.138066",
#                          "ticker_sentiment_score": "0.072464",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "EXCLUSIVE: Top 20 Most-Searched Tickers On Pro In December 2024 - Where Do Tesla, Nvidia, Quantum Computing Stock Rank? - Apple  ( NASDAQ:AAPL ) ",
#                "url": "https://www.benzinga.com/trading-ideas/25/01/42755273/exclusive-top-20-most-searched-tickers-on-benzinga-pro-in-december-2024-where-do-tesla-nvidia-quant",
#                "time_published": "20250101T141541",
#                "authors": [
#                     "Chris Katje"
#                ],
#                "summary": "Each trading day features hundreds of headlines and press releases on Benzinga Pro, a source for traders to see the latest news on the overall market and individual tickers. Here is a look at the most-searched stocks on Benzinga Pro for December 2024.",
#                "banner_image": "https://cdn.benzinga.com/files/images/story/2025/01/01/Ticker-Board-With-Stock-Market-Prices--P.jpeg?width=1200&height=800&fit=crop",
#                "source": "Benzinga",
#                "category_within_source": "Trading",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.998962"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Finance",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Blockchain",
#                          "relevance_score": "0.158519"
#                     }
#                ],
#                "overall_sentiment_score": 0.173495,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSTR",
#                          "relevance_score": "0.056674",
#                          "ticker_sentiment_score": "0.124941",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.056674",
#                          "ticker_sentiment_score": "-0.147956",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.113062",
#                          "ticker_sentiment_score": "0.066368",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "SOUN",
#                          "relevance_score": "0.056674",
#                          "ticker_sentiment_score": "0.068194",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "TSLA",
#                          "relevance_score": "0.056674",
#                          "ticker_sentiment_score": "0.097927",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "QBTS",
#                          "relevance_score": "0.056674",
#                          "ticker_sentiment_score": "0.040935",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "SMCI",
#                          "relevance_score": "0.056674",
#                          "ticker_sentiment_score": "0.190984",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "IVZ",
#                          "relevance_score": "0.056674",
#                          "ticker_sentiment_score": "0.065029",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "DJT",
#                          "relevance_score": "0.113062",
#                          "ticker_sentiment_score": "0.113798",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "CRYPTO:BTC",
#                          "relevance_score": "0.223866",
#                          "ticker_sentiment_score": "0.210416",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     }
#                ]
#           },
#           {
#                "title": "Competitor Analysis: Evaluating Apple And Competitors In Technology Hardware, Storage & Peripherals Industry - Apple  ( NASDAQ:AAPL ) ",
#                "url": "https://www.benzinga.com/insights/news/25/01/42755470/competitor-analysis-evaluating-apple-and-competitors-in-technology-hardware-storage-amp-peripherals",
#                "time_published": "20250101T150027",
#                "authors": [
#                     "Benzinga Insights"
#                ],
#                "summary": "In the ever-evolving and intensely competitive business landscape, conducting a thorough company analysis is of utmost importance for investors and industry followers.",
#                "banner_image": "https://www.benzinga.com/files/images/story/2025/1735743624_0.png",
#                "source": "Benzinga",
#                "category_within_source": "Trading",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.875462"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "1.0"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.5855"
#                     }
#                ],
#                "overall_sentiment_score": 0.214462,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.464844",
#                          "ticker_sentiment_score": "0.250432",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     }
#                ]
#           },
#           {
#                "title": "Warren Buffett Says Buy S&P 500, But This Tech Investor Warns Of A 'Rude Awakening' - Microsoft  ( NASDAQ:MSFT ) , Apple  ( NASDAQ:AAPL ) ",
#                "url": "https://www.benzinga.com/markets/25/01/42756619/warren-buffett-says-buy-sp-500-but-this-tech-investor-warns-of-a-rude-awakening",
#                "time_published": "20250101T180019",
#                "authors": [
#                     "Bibhu Pattnaik"
#                ],
#                "summary": "Investing in the S&P 500 index could be a high-risk gamble, suggests Palihapitiya, as a few tech giants sway market stability. Palihapitiya contrasts Buffett's conservative investment approach with cautionary advice amid his own SPAC endorsements.",
#                "banner_image": "https://cdn.benzinga.com/files/images/story/2025/01/01/Do-You-Know-Warren-Buffetts-Berkshire-Ha_1.jpeg?width=1200&height=800&fit=crop",
#                "source": "Benzinga",
#                "category_within_source": "Markets",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.5"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.967645"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.5"
#                     }
#                ],
#                "overall_sentiment_score": 0.036231,
#                "overall_sentiment_label": "Neutral",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.160633",
#                          "ticker_sentiment_score": "-0.051049",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.160633",
#                          "ticker_sentiment_score": "-0.051049",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.160633",
#                          "ticker_sentiment_score": "-0.051049",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "Tim Cook, Mark Zuckerberg, Elon Musk, And More: Tech Moguls Post Upbeat New Year Greetings: 'Have A Good Feeling About 2025' - Alphabet  ( NASDAQ:GOOG ) , Apple  ( NASDAQ:AAPL ) ",
#                "url": "https://www.benzinga.com/25/01/42758055/tim-cook-sundar-pichai-elon-musk-mark-zuckerberg-and-more-how-top-tech-ceos-ushered-in-2025-with-new-year-cheers-",
#                "time_published": "20250102T022801",
#                "authors": [
#                     "Ananya Gairola"
#                ],
#                "summary": "As the world stepped into 2025, some of the biggest names in tech took to social media to share their New Year's greetings, hopes, and bold visions for the future. What Happened: Taking to X, formerly Twitter, Apple Inc. AAPL CEO Tim Cook expressed wishes for health and happiness for all.",
#                "banner_image": "https://editorial-assets.benzinga.com/wp-content/uploads/2025/01/01205153/Screenshot-2025-01-02-at-7.21.42%E2%80%AFAM-1024x527.png",
#                "source": "Benzinga",
#                "category_within_source": "News",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.796627"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Finance",
#                          "relevance_score": "0.333333"
#                     }
#                ],
#                "overall_sentiment_score": 0.411729,
#                "overall_sentiment_label": "Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "GOOG",
#                          "relevance_score": "0.165598",
#                          "ticker_sentiment_score": "0.252601",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "META",
#                          "relevance_score": "0.165598",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.246167",
#                          "ticker_sentiment_score": "0.069175",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "BTSDF",
#                          "relevance_score": "0.165598",
#                          "ticker_sentiment_score": "0.427988",
#                          "ticker_sentiment_label": "Bullish"
#                     },
#                     {
#                          "ticker": "TSLA",
#                          "relevance_score": "0.246167",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "MS",
#                          "relevance_score": "0.083251",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "Apple Discounts iPhone 16 Prices In China By Up To $68.5 As It Battles Huawei's Resurgence In The Country - Apple  ( NASDAQ:AAPL ) ",
#                "url": "https://www.benzinga.com/media/25/01/42759147/apple-discounts-iphone-16-prices-in-china-by-up-to-68-5-as-it-battles-huaweis-resurgence-in-the-country",
#                "time_published": "20250102T081345",
#                "authors": [
#                     "Ananya Gairola"
#                ],
#                "summary": "Apple Inc. AAPL is offering discounts of up to 500 yuan ( $68.50 ) on its iPhone 16 models in China as it faces increasing competition from Huawei Technologies. What Happened: Apple has launched a rare promotional event in China, set to run from Jan. 4 to Jan. 7, 2025, reported Reuters.",
#                "banner_image": "https://cdn.benzinga.com/files/images/story/2025/01/02/Apple-iPhone-16-Pro-iPhone-16-Pro-Max.jpeg?width=1200&height=800&fit=crop",
#                "source": "Benzinga",
#                "category_within_source": "News",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "1.0"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.108179"
#                     }
#                ],
#                "overall_sentiment_score": 0.188415,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "BABA",
#                          "relevance_score": "0.086556",
#                          "ticker_sentiment_score": "-0.046197",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "XIACY",
#                          "relevance_score": "0.086556",
#                          "ticker_sentiment_score": "0.130676",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.33628",
#                          "ticker_sentiment_score": "0.172626",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     }
#                ]
#           },
#           {
#                "title": "Should iShares Core S&P 500 ETF  ( IVV )  Be on Your Investing Radar?",
#                "url": "https://www.zacks.com/stock/news/2390545/should-ishares-core-sp-500-etf-ivv-be-on-your-investing-radar",
#                "time_published": "20250102T112007",
#                "authors": [
#                     "Zacks Equity Research"
#                ],
#                "summary": "Style Box ETF report for ...",
#                "banner_image": "https://staticx-tuner.zacks.com/images/default_article_images/default64.jpg",
#                "source": "Zacks Commentary",
#                "category_within_source": "n/a",
#                "source_domain": "www.zacks.com",
#                "topics": [
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.5"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "1.0"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.5"
#                     }
#                ],
#                "overall_sentiment_score": 0.180111,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.136499",
#                          "ticker_sentiment_score": "0.072027",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.136499",
#                          "ticker_sentiment_score": "0.072027",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.136499",
#                          "ticker_sentiment_score": "0.072027",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "UBS Cuts iPhone Sales Forecast For December Amid Stiff Competition From Rivals, Maintains Neutral Rating - Apple  ( NASDAQ:AAPL ) ",
#                "url": "https://www.benzinga.com/25/01/42760822/ubs-cuts-iphone-sales-forecast-for-december-as-apple-faces-stiff-competition-from-other-players",
#                "time_published": "20250102T112223",
#                "authors": [
#                     "Rishabh Mishra"
#                ],
#                "summary": "UBS forecasts lower iPhone sales forecast. Apple competitors' market share increase. After Apple Inc.'s AAPL market share fell in China in the third quarter of 2024, UBS has forecast weaker iPhone sales in the month of December.",
#                "banner_image": "https://editorial-assets.benzinga.com/wp-content/uploads/2025/01/02042528/AAPL-ANR-.png",
#                "source": "Benzinga",
#                "category_within_source": "Markets",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.650727"
#                     },
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.684621"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.5"
#                     },
#                     {
#                          "topic": "Finance",
#                          "relevance_score": "0.5"
#                     }
#                ],
#                "overall_sentiment_score": 0.110516,
#                "overall_sentiment_label": "Neutral",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.574748",
#                          "ticker_sentiment_score": "0.161565",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "BCS",
#                          "relevance_score": "0.079392",
#                          "ticker_sentiment_score": "-0.059481",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "XIACY",
#                          "relevance_score": "0.079392",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "MS",
#                          "relevance_score": "0.158",
#                          "ticker_sentiment_score": "-0.085002",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "2 Magnificent Artificial Intelligence  ( AI )  Stocks to Buy in 2025",
#                "url": "https://www.fool.com/investing/2025/01/02/2-artificial-intelligence-ai-stocks-that-could-mak/",
#                "time_published": "20250102T121500",
#                "authors": [
#                     "Keithen Drury"
#                ],
#                "summary": "The artificial intelligence ( AI ) investing sector is a gold mine for finding companies with market-beating potential. Nvidia ( NASDAQ: NVDA ) and Taiwan Semiconductor Manufacturing ( NYSE: TSM ) are among the stocks that I think can outperform the market over the next five years.",
#                "banner_image": "https://media.ycharts.com/charts/60a80c0c6b4c4ce8f0cf93a0d3824137.png",
#                "source": "Motley Fool",
#                "category_within_source": "n/a",
#                "source_domain": "www.fool.com",
#                "topics": [
#                     {
#                          "topic": "Retail & Wholesale",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.929393"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.995973"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.333333"
#                     }
#                ],
#                "overall_sentiment_score": 0.31529,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.068698",
#                          "ticker_sentiment_score": "0.110389",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.657011",
#                          "ticker_sentiment_score": "0.482756",
#                          "ticker_sentiment_label": "Bullish"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.068698",
#                          "ticker_sentiment_score": "0.110389",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AMZN",
#                          "relevance_score": "0.068698",
#                          "ticker_sentiment_score": "0.110389",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "TSM",
#                          "relevance_score": "0.136888",
#                          "ticker_sentiment_score": "0.244321",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     }
#                ]
#           },
#           {
#                "title": "Broadcom Thrives with 114% Stock Surge in AI Boom, While Intel Faces Steep Decline - Broadcom  ( NASDAQ:AVGO ) , Intel  ( NASDAQ:INTC ) ",
#                "url": "https://www.benzinga.com/media/25/01/42762874/broadcom-thrives-with-114-stock-surge-in-ai-boom-while-intel-faces-steep-decline",
#                "time_published": "20250102T130929",
#                "authors": [
#                     "Anusuya Lahiri"
#                ],
#                "summary": "The year 2024 proved very eventful for the semiconductor companies in the U.S. tech sector. It rewarded those, including Nvidia Corp NVDA and Broadcom Inc AVGO, that successfully tapped the artificial intelligence wave while punishing those that failed, like Intel Corp INTC.",
#                "banner_image": "https://editorial-assets.benzinga.com/wp-content/uploads/2025/01/02060246/newplot.png",
#                "source": "Benzinga",
#                "category_within_source": "News",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.918141"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.77141"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Finance",
#                          "relevance_score": "0.333333"
#                     }
#                ],
#                "overall_sentiment_score": 0.096523,
#                "overall_sentiment_label": "Neutral",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.120431",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "GOOG",
#                          "relevance_score": "0.238133",
#                          "ticker_sentiment_score": "0.08153",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "META",
#                          "relevance_score": "0.120431",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.455525",
#                          "ticker_sentiment_score": "0.146656",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.120431",
#                          "ticker_sentiment_score": "-0.135115",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AVGO",
#                          "relevance_score": "0.551295",
#                          "ticker_sentiment_score": "0.27507",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "QCOM",
#                          "relevance_score": "0.120431",
#                          "ticker_sentiment_score": "-0.135115",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "INTC",
#                          "relevance_score": "0.595343",
#                          "ticker_sentiment_score": "-0.039415",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AMD",
#                          "relevance_score": "0.179788",
#                          "ticker_sentiment_score": "0.053402",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "ARM",
#                          "relevance_score": "0.120431",
#                          "ticker_sentiment_score": "-0.135115",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "GS",
#                          "relevance_score": "0.060388",
#                          "ticker_sentiment_score": "0.036349",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "TSM",
#                          "relevance_score": "0.120431",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "Assessing Apple's Performance Against Competitors In Technology Hardware, Storage & Peripherals Industry - Apple  ( NASDAQ:AAPL ) ",
#                "url": "https://www.benzinga.com/insights/news/25/01/42765848/assessing-apples-performance-against-competitors-in-technology-hardware-storage-amp-peripherals-ind",
#                "time_published": "20250102T150028",
#                "authors": [
#                     "Benzinga Insights"
#                ],
#                "summary": "In today's rapidly changing and fiercely competitive business landscape, it is vital for investors and industry enthusiasts to carefully evaluate companies. In this article, we will perform a comprehensive industry comparison, evaluating Apple AAPL against its key competitors in the Technology ...",
#                "banner_image": "https://www.benzinga.com/files/images/story/2025/1735830025_0.png",
#                "source": "Benzinga",
#                "category_within_source": "News",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.95493"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "1.0"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.623304"
#                     }
#                ],
#                "overall_sentiment_score": 0.28935,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.516883",
#                          "ticker_sentiment_score": "0.373433",
#                          "ticker_sentiment_label": "Bullish"
#                     }
#                ]
#           },
#           {
#                "title": "Market Clubhouse Morning Memo - January 2nd, 2024  ( Trade Strategy For SPY, QQQ, AAPL, MSFT, NVDA, GOOGL, META and TSLA ) ",
#                "url": "https://www.benzinga.com/trading-ideas/25/01/42771813/market-clubhouse-morning-memo-january-2nd-2024-trade-strategy-for-spy-qqq-aapl-msft-nvda-googl-meta",
#                "time_published": "20250102T180252",
#                "authors": [
#                     "RIPS"
#                ],
#                "summary": "Good Morning Traders! In today's Market Clubhouse Morning Memo, we will discuss SPY, QQQ, AAPL, MSFT, NVDA, GOOGL, META, and TSLA. Our proprietary formula, exclusive to Market Clubhouse, dictates these price levels. This dynamic equation takes into account price, volume, and options flow.",
#                "banner_image": "https://www.benzinga.com/next-assets/images/schema-image-default.png",
#                "source": "Benzinga",
#                "category_within_source": "Trading",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.5"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.752319"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.5"
#                     }
#                ],
#                "overall_sentiment_score": 0.114292,
#                "overall_sentiment_label": "Neutral",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.097589",
#                          "ticker_sentiment_score": "0.155584",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "GOOG",
#                          "relevance_score": "0.032602",
#                          "ticker_sentiment_score": "0.075187",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.129866",
#                          "ticker_sentiment_score": "0.008634",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "SPGI",
#                          "relevance_score": "0.032602",
#                          "ticker_sentiment_score": "-0.044821",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.129866",
#                          "ticker_sentiment_score": "-0.068991",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "TSLA",
#                          "relevance_score": "0.161928",
#                          "ticker_sentiment_score": "0.036983",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "Some Investors Are Selling Apple Stock Thursday: Here's Why - Apple  ( NASDAQ:AAPL ) ",
#                "url": "https://www.benzinga.com/news/global/25/01/42773823/some-investors-are-selling-apple-stock-thursday-heres-why",
#                "time_published": "20250102T192509",
#                "authors": [
#                     "Adam Eckert"
#                ],
#                "summary": "Apple is running a four-day promotional period, discounting iPhone models in China by up to 500 yuan. Apple is reportedly battling market share declines as local competition intensifies in China. Get Monthly Picks of Market's Fastest Movers",
#                "banner_image": "https://cdn.benzinga.com/files/images/story/2025/01/02/Apple-iOS-18-hero.jpeg?width=1200&height=800&fit=crop",
#                "source": "Benzinga",
#                "category_within_source": "News",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "1.0"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.684621"
#                     }
#                ],
#                "overall_sentiment_score": 0.100772,
#                "overall_sentiment_label": "Neutral",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.82023",
#                          "ticker_sentiment_score": "0.185768",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     }
#                ]
#           },
#           {
#                "title": "Stock Market's New Year Mantra - Trump, Bitcoin, AI, And Quantum Will Fix Everything - EOG Resources  ( NYSE:EOG ) , Devon Energy  ( NYSE:DVN ) ",
#                "url": "https://www.benzinga.com/trading-ideas/25/01/42773997/stock-markets-new-year-mantra-trump-bitcoin-ai-and-quantum-will-fix-everything",
#                "time_published": "20250102T193210",
#                "authors": [
#                     "The Arora Report"
#                ],
#                "summary": "To gain an edge, this is what you need to know today. An enlarged chart of SPDR S&P 500 ETF Trust which represents the benchmark stock market index S&P 500 ( SPX ) . Trump will fix everything. At The Arora Report, we would like nothing more than to see Trump succeed.",
#                "banner_image": "https://thearorareport.com/wp-content/uploads/2025/01/2025-01-02_08h31_20.png",
#                "source": "Benzinga",
#                "category_within_source": "Trading",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Economy - Monetary",
#                          "relevance_score": "0.158519"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "1.0"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.25"
#                     },
#                     {
# ...
#                "source": "Benzinga",
#                "category_within_source": "News",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.214378"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.5"
#                     },
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.918141"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.5"
#                     }
#                ],
#                "overall_sentiment_score": -0.13699,
#                "overall_sentiment_label": "Neutral",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.208464",
#                          "ticker_sentiment_score": "-0.251129",
#                          "ticker_sentiment_label": "Somewhat-Bearish"
#                     },
#                     {
#                          "ticker": "TSLA",
#                          "relevance_score": "0.208464",
#                          "ticker_sentiment_score": "-0.251129",
#                          "ticker_sentiment_label": "Somewhat-Bearish"
#                     },
#                     {
#                          "ticker": "STM",
#                          "relevance_score": "0.813694",
#                          "ticker_sentiment_score": "-0.360956",
#                          "ticker_sentiment_label": "Bearish"
#                     },
#                     {
#                          "ticker": "ON",
#                          "relevance_score": "0.105141",
#                          "ticker_sentiment_score": "-0.168287",
#                          "ticker_sentiment_label": "Somewhat-Bearish"
#                     }
#                ]
#           },
#           {
#                "title": "Taiwan Bans DeepSeek AI Over Security Concerns, Joins Global Scrutiny of Chinese Tech - Taiwan Semiconductor  ( NYSE:TSM ) ",
#                "url": "https://www.benzinga.com/government/regulations/25/01/43401844/taiwan-bans-deepseek-ai-over-security-concerns-joins-global-scrutiny-of-chinese-tech",
#                "time_published": "20250131T191242",
#                "authors": [
#                     "Anusuya Lahiri"
#                ],
#                "summary": "Taiwan bans government use of DeepSeek AI over security risks, aligning with U.S. stance against Chinese tech. DeepSeek AI overtakes ChatGPT in downloads, faces global scrutiny as U.S. probes Nvidia chip access violations. Get the Real Story Behind Every Major Earnings Report",
#                "banner_image": "https://cdn.benzinga.com/files/images/story/2025/01/31/TSMCs-Challenges.jpeg?width=1200&height=800&fit=crop",
#                "source": "Benzinga",
#                "category_within_source": "News",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.266143"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.451494"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Finance",
#                          "relevance_score": "0.333333"
#                     }
#                ],
#                "overall_sentiment_score": 0.138703,
#                "overall_sentiment_label": "Neutral",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.251247",
#                          "ticker_sentiment_score": "-0.027969",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.169081",
#                          "ticker_sentiment_score": "0.283056",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "BCS",
#                          "relevance_score": "0.085022",
#                          "ticker_sentiment_score": "0.013892",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "TSM",
#                          "relevance_score": "0.251247",
#                          "ticker_sentiment_score": "-0.103688",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "EXCLUSIVE: This 'Magnificent 7' Stock Will Feel The Pinch Of Fed's Rate Decision, Poll Shows - Apple  ( NASDAQ:AAPL ) , Amazon.com  ( NASDAQ:AMZN ) ",
#                "url": "https://www.benzinga.com/trading-ideas/25/01/43403758/exclusive-this-magnificent-7-stock-will-feel-the-pinch-of-feds-rate-decision-poll-shows",
#                "time_published": "20250131T205446",
#                "authors": [
#                     "Chris Katje"
#                ],
#                "summary": "A Benzinga Reader poll asks which Magnificent 7 stock could be hit hardest by the Fed's decision to leave rates unchanged. The Federal Reserve cut rates three straight times prior to January's meeting. Get Wall Street's Hottest Chart Every Morning",
#                "banner_image": "https://cdn.benzinga.com/files/images/story/2025/01/31/The-Magnificent-Seven--7-Of-Largest-Us-T.jpeg?width=1200&height=800&fit=crop",
#                "source": "Benzinga",
#                "category_within_source": "Trading",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Economy - Monetary",
#                          "relevance_score": "0.838487"
#                     },
#                     {
#                          "topic": "Retail & Wholesale",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.87644"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.333333"
#                     }
#                ],
#                "overall_sentiment_score": 0.194233,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.19117",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "GOOG",
#                          "relevance_score": "0.064276",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "META",
#                          "relevance_score": "0.128135",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.19117",
#                          "ticker_sentiment_score": "0.026888",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.064276",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "TSLA",
#                          "relevance_score": "0.128135",
#                          "ticker_sentiment_score": "0.025968",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AMZN",
#                          "relevance_score": "0.128135",
#                          "ticker_sentiment_score": "0.0",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "Apple Unusual Options Activity - Apple  ( NASDAQ:AAPL ) ",
#                "url": "https://www.benzinga.com/insights/options/25/01/43403759/apple-unusual-options-activity",
#                "time_published": "20250131T205446",
#                "authors": [
#                     "Benzinga Insights"
#                ],
#                "summary": "Deep-pocketed investors have adopted a bearish approach towards Apple AAPL, and it's something market players shouldn't ignore. Our tracking of public options records at Benzinga unveiled this significant move today.",
#                "banner_image": "https://www.benzinga.com/files/images/story/2025/1738356883_0.png",
#                "source": "Benzinga",
#                "category_within_source": "Markets",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.962106"
#                     },
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.310843"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.5"
#                     },
#                     {
#                          "topic": "Finance",
#                          "relevance_score": "0.5"
#                     }
#                ],
#                "overall_sentiment_score": 0.173426,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "GS",
#                          "relevance_score": "0.062271",
#                          "ticker_sentiment_score": "0.020041",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.815863",
#                          "ticker_sentiment_score": "0.24908",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "BCS",
#                          "relevance_score": "0.062271",
#                          "ticker_sentiment_score": "0.020041",
#                          "ticker_sentiment_label": "Neutral"
#                     }
#                ]
#           },
#           {
#                "title": "Stocks Trim DeepSeek Losses, Fed Holds Steady, Trump Slaps 25% Tariffs On Canada, Mexico: This Week In The Markets - Apple  ( NASDAQ:AAPL ) , Amazon.com  ( NASDAQ:AMZN ) ",
#                "url": "https://www.benzinga.com/25/01/43404983/stocks-trim-deepseek-losses-fed-holds-steady-trump-slaps-25-tariffs-on-canada-mexico-this-week-in-the-markets",
#                "time_published": "20250131T213650",
#                "authors": [
#                     "Piero Cingari"
#                ],
#                "summary": "US stocks rebounded in four sessions after AI-driven losses, as strong earnings and a less hawkish Fed fueled buying. Trump reiterated 25% tariffs on Mexico, Canada and 10% on China. The White House confirmed implementation on Saturday, rattling markets.",
#                "banner_image": "https://cdn.benzinga.com/files/images/story/2025/01/31/wall-street-ai15.png?width=1200&height=800&fit=crop",
#                "source": "Benzinga",
#                "category_within_source": "Markets",
#                "source_domain": "www.benzinga.com",
#                "topics": [
#                     {
#                          "topic": "Economy - Monetary",
#                          "relevance_score": "0.576289"
#                     },
#                     {
#                          "topic": "Financial Markets",
#                          "relevance_score": "0.858979"
#                     },
#                     {
#                          "topic": "Manufacturing",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Earnings",
#                          "relevance_score": "0.857896"
#                     },
#                     {
#                          "topic": "Energy & Transportation",
#                          "relevance_score": "0.333333"
#                     },
#                     {
#                          "topic": "Technology",
#                          "relevance_score": "0.333333"
#                     }
#                ],
#                "overall_sentiment_score": 0.176223,
#                "overall_sentiment_label": "Somewhat-Bullish",
#                "ticker_sentiment": [
#                     {
#                          "ticker": "MSFT",
#                          "relevance_score": "0.130217",
#                          "ticker_sentiment_score": "0.186592",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "NVDA",
#                          "relevance_score": "0.130217",
#                          "ticker_sentiment_score": "-0.131724",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "AAPL",
#                          "relevance_score": "0.130217",
#                          "ticker_sentiment_score": "0.103474",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "NCLH",
#                          "relevance_score": "0.130217",
#                          "ticker_sentiment_score": "0.28562",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "GM",
#                          "relevance_score": "0.130217",
#                          "ticker_sentiment_score": "0.306433",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     },
#                     {
#                          "ticker": "UPS",
#                          "relevance_score": "0.130217",
#                          "ticker_sentiment_score": "-0.140949",
#                          "ticker_sentiment_label": "Neutral"
#                     },
#                     {
#                          "ticker": "RCL",
#                          "relevance_score": "0.194242",
#                          "ticker_sentiment_score": "0.361411",
#                          "ticker_sentiment_label": "Bullish"
#                     },
#                     {
#                          "ticker": "CCL",
#                          "relevance_score": "0.130217",
#                          "ticker_sentiment_score": "0.28562",
#                          "ticker_sentiment_label": "Somewhat-Bullish"
#                     }
#                ]
#           }
#      ]
# }

# %% [markdown]
# # Real news data gathering starts from here.
# Pros: Gives title, summary, published date, stock symbol, news sentiment score, and news sentiment label
#
# Cons: Can't provided data for year 2020 or before, (tentative I have to check for 21 and 22 also, provides data from 2023)

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
# Your Alpha Vantage API key
ALPHA_VANTAGE_API_KEY = '1RZHEEKZF7GJSSST'
BASE_URL = "https://www.alphavantage.co/query?function=NEWS_SENTIMENT"

# %%
# List of tickers for which to retrieve news
tickers = ['AAPL', 'TSLA', 'AMZN', 'NKE', 'NVDA']

# Overall date range for the news retrieval
overall_start = datetime(2025, 1, 1)
overall_end = datetime(2025, 3, 31)

# %%
def get_monthly_ranges(start_date, end_date):
    """
    Breaks the overall date range into monthly intervals.
    Returns a list of tuples, each with a (formatted_month_start, formatted_month_end) string,
    using the format 'YYYYMMDDTHHMM'.
    """
    ranges = []
    current = start_date
    while current <= end_date:
        month_start = current.replace(day=1)
        month_end = (month_start + relativedelta(months=1)) - timedelta(days=1)
        # Ensure the month_end does not exceed the overall end date
        if month_end > end_date:
            month_end = end_date
        # Format both start and end dates to 'YYYYMMDDTHHMM'
        start_str = month_start.strftime("%Y%m%dT%H%M")
        end_str = month_end.strftime("%Y%m%dT%H%M")
        ranges.append((start_str, end_str))
        current = month_end + timedelta(days=1)
    return ranges

monthly_ranges = get_monthly_ranges(overall_start, overall_end)
print(monthly_ranges)
# Out:
# [('20250101T0000', '20250131T0000'), ('20250201T0000', '20250228T0000'), ('20250301T0000', '20250331T0000')]

# %%
def get_url(ticker,start_date,end_date,api_key,limit=1000,sort='EARLIEST'):
    ticker_url = BASE_URL
    ticker_url += '&tickers=' + ticker
    ticker_url += '&apikey=' + api_key
    ticker_url += '&time_from=' + start_date
    ticker_url += '&time_to=' + end_date
    ticker_url += '&sort=' + sort
    ticker_url += '&limit=' + str(limit)
    return ticker_url

# %%
def get_news_for_ticker_alphavantage(ticker_url):
    """
    Retrieves news for a given ticker from the Alpha Vantage NEWS_SENTIMENT endpoint
    for the specified date range.
    
    Parameters:
      - ticker_url: API call url
      
    Returns:
      A list of dictionaries, each representing an article with:
        - published_date: Publication date (string format from API)
        - title: Article title
        - summary: Article summary
        - ticker: The current ticker symbol
        - ticker_sentiment_score: Sentiment score for the ticker (if available)
        - ticker_sentiment_label: Sentiment label for the ticker (if available)
    """
    response = requests.get(ticker_url)
    data = response.json()
    
    articles = []
    # Check if the response contains a news feed
    if 'feed' in data:
        for item in data['feed']:
            published_date = item.get("time_published", "")  # e.g., "20250101T100600"
            title = item.get("title", "")
            summary = item.get("summary", "")
            
            # Extract ticker sentiment details for the current ticker
            ticker_sentiments = item.get("ticker_sentiment", [])
            ticker_sentiment_score = None
            ticker_sentiment_label = None
            for sentiment in ticker_sentiments:
                if sentiment.get("ticker") == ticker:
                    ticker_sentiment_score = sentiment.get("ticker_sentiment_score")
                    ticker_sentiment_label = sentiment.get("ticker_sentiment_label")
                    break

            articles.append({
                "published_date": published_date,
                "title": title,
                "summary": summary,
                "ticker": ticker,
                "ticker_sentiment_score": ticker_sentiment_score,
                "ticker_sentiment_label": ticker_sentiment_label
            })
    else:
        print(f"No news feed returned for {ticker} between {start_date.strftime('%Y-%m-%d')} and {end_date.strftime('%Y-%m-%d')}. Response: {data}")
    return articles

# %%
for ticker in tickers:
    ticker_articles = []
    for start, end in monthly_ranges:
        print(f"Fetching {ticker} news from {start} to {end}")
        ticker_url = get_url(ticker,start,end,ALPHA_VANTAGE_API_KEY)
        print(ticker_url)
        articles = get_news_for_ticker_alphavantage(ticker_url)
        ticker_articles.extend(articles)
    
    # Optionally deduplicate articles based on title and published date to remove overlaps
    df = pd.DataFrame(ticker_articles).drop_duplicates(subset=["title", "published_date"])
    df.to_csv(f"../results/{ticker}_alpha_news_data.csv", index=False)
    #all_articles.append(df)
    
print("All News articles saved.")
# Out:
# Fetching AAPL news from 20250101T0000 to 20250131T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=1RZHEEKZF7GJSSST&time_from=20250101T0000&time_to=20250131T0000&sort=EARLIEST&limit=1000
# Fetching AAPL news from 20250201T0000 to 20250228T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=1RZHEEKZF7GJSSST&time_from=20250201T0000&time_to=20250228T0000&sort=EARLIEST&limit=1000
# Fetching AAPL news from 20250301T0000 to 20250331T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=1RZHEEKZF7GJSSST&time_from=20250301T0000&time_to=20250331T0000&sort=EARLIEST&limit=1000
# Fetching TSLA news from 20250101T0000 to 20250131T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=TSLA&apikey=1RZHEEKZF7GJSSST&time_from=20250101T0000&time_to=20250131T0000&sort=EARLIEST&limit=1000
# Fetching TSLA news from 20250201T0000 to 20250228T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=TSLA&apikey=1RZHEEKZF7GJSSST&time_from=20250201T0000&time_to=20250228T0000&sort=EARLIEST&limit=1000
# Fetching TSLA news from 20250301T0000 to 20250331T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=TSLA&apikey=1RZHEEKZF7GJSSST&time_from=20250301T0000&time_to=20250331T0000&sort=EARLIEST&limit=1000
# Fetching AMZN news from 20250101T0000 to 20250131T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AMZN&apikey=1RZHEEKZF7GJSSST&time_from=20250101T0000&time_to=20250131T0000&sort=EARLIEST&limit=1000
# Fetching AMZN news from 20250201T0000 to 20250228T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AMZN&apikey=1RZHEEKZF7GJSSST&time_from=20250201T0000&time_to=20250228T0000&sort=EARLIEST&limit=1000
# Fetching AMZN news from 20250301T0000 to 20250331T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AMZN&apikey=1RZHEEKZF7GJSSST&time_from=20250301T0000&time_to=20250331T0000&sort=EARLIEST&limit=1000
# Fetching NKE news from 20250101T0000 to 20250131T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=NKE&apikey=1RZHEEKZF7GJSSST&time_from=20250101T0000&time_to=20250131T0000&sort=EARLIEST&limit=1000
# Fetching NKE news from 20250201T0000 to 20250228T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=NKE&apikey=1RZHEEKZF7GJSSST&time_from=20250201T0000&time_to=20250228T0000&sort=EARLIEST&limit=1000
# Fetching NKE news from 20250301T0000 to 20250331T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=NKE&apikey=1RZHEEKZF7GJSSST&time_from=20250301T0000&time_to=20250331T0000&sort=EARLIEST&limit=1000
# Fetching NVDA news from 20250101T0000 to 20250131T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=NVDA&apikey=1RZHEEKZF7GJSSST&time_from=20250101T0000&time_to=20250131T0000&sort=EARLIEST&limit=1000
# Fetching NVDA news from 20250201T0000 to 20250228T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=NVDA&apikey=1RZHEEKZF7GJSSST&time_from=20250201T0000&time_to=20250228T0000&sort=EARLIEST&limit=1000
# Fetching NVDA news from 20250301T0000 to 20250331T0000
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=NVDA&apikey=1RZHEEKZF7GJSSST&time_from=20250301T0000&time_to=20250331T0000&sort=EARLIEST&limit=1000
# News articles saved to stock_news_data.csv
